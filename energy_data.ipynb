# %%
import pandas as pd
import scipy.stats as stats

# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats
import matplotlib

# %%
df = pd.read_csv("MER_T07_06.csv")
df.head()
# Out:
#        MSN  YYYYMM      Value  Column_Order  \
# 0  ESRCPUS  194913  66791.968             1
# 1  ESRCPUS  195013   72200.34             1
# 2  ESRCPUS  195113  83092.821             1
# 3  ESRCPUS  195213  93544.873             1
# 4  ESRCPUS  195313  104146.29             1
#
#                                          Description                   Unit
# 0  Electricity Retail Sales to the Residential Se...  Million Kilowatthours
# 1  Electricity Retail Sales to the Residential Se...  Million Kilowatthours
# 2  Electricity Retail Sales to the Residential Se...  Million Kilowatthours
# 3  Electricity Retail Sales to the Residential Se...  Million Kilowatthours
# 4  Electricity Retail Sales to the Residential Se...  Million Kilowatthours

# %%
df.dtypes
df['Year']=df['YYYYMM'].astype(str).str[:4]
df['Month'] = df['YYYYMM'].astype(str).str[4:6]
df['Year']=df['Year'].astype(int)
df['Month']=df['Month'].astype(int)
df
# Out:
#           MSN  YYYYMM       Value  Column_Order  \
# 0     ESRCPUS  194913   66791.968             1
# 1     ESRCPUS  195013    72200.34             1
# 2     ESRCPUS  195113   83092.821             1
# 3     ESRCPUS  195213   93544.873             1
# 4     ESRCPUS  195313   104146.29             1
# ...       ...     ...         ...           ...
# 4510  ELTCPUS  202006  326870.517             7
# 4511  ELTCPUS  202007  386633.464             7
# 4512  ELTCPUS  202008  375897.357             7
# 4513  ELTCPUS  202009  328843.084             7
# 4514  ELTCPUS  202010  306514.316             7
#
#                                             Description  \
# 0     Electricity Retail Sales to the Residential Se...
# 1     Electricity Retail Sales to the Residential Se...
# 2     Electricity Retail Sales to the Residential Se...
# 3     Electricity Retail Sales to the Residential Se...
# 4     Electricity Retail Sales to the Residential Se...
# ...

# %%
df_condensed=df[df['Year']>=2016]
df_condensed
# Out:
#           MSN  YYYYMM       Value  Column_Order  \
# 583   ESRCPUS  201601  130971.848             1
# 584   ESRCPUS  201602  115959.425             1
# 585   ESRCPUS  201603  100226.575             1
# 586   ESRCPUS  201604    88244.34             1
# 587   ESRCPUS  201605    94198.03             1
# ...       ...     ...         ...           ...
# 4510  ELTCPUS  202006  326870.517             7
# 4511  ELTCPUS  202007  386633.464             7
# 4512  ELTCPUS  202008  375897.357             7
# 4513  ELTCPUS  202009  328843.084             7
# 4514  ELTCPUS  202010  306514.316             7
#
#                                             Description  \
# 583   Electricity Retail Sales to the Residential Se...
# 584   Electricity Retail Sales to the Residential Se...
# 585   Electricity Retail Sales to the Residential Se...
# 586   Electricity Retail Sales to the Residential Se...
# 587   Electricity Retail Sales to the Residential Se...
# ...

# %%
df_condensed['Value'].astype(float)
# Out:
# 583     130971.848
# 584     115959.425
# 585     100226.575
# 586      88244.340
# 587      94198.030
#            ...
# 4510    326870.517
# 4511    386633.464
# 4512    375897.357
# 4513    328843.084
# 4514    306514.316
# Name: Value, Length: 434, dtype: float64

# %%
df_usetype=df_condensed.groupby(['Description'])

# %%
#df_time = pd.DataFrame({'lab':['A', 'B', 'C'], 'val':[10, 30, 20]})
df_condensed.plot (kind='bar', stacked=True)
#test5.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:>

# %%
#date = df_condensed['YYYYMM']
use_type = df_usetype
energy_use = df_condensed['Value']

df_plot = pd.DataFrame({'Date': date,
                        'Use Type': use_type,
                        'Energy Used':energy_use})

df_plot.plot(kind='bar', stacked=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-e7745edceffb> in <module>
#       3 energy_use = df_condensed['Value']
#       4
# ----> 5 df_plot = pd.DataFrame({'Date': date,
#       6                         'Use Type': use_type,
#       7                         'Energy Used':energy_use})
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
# ...

# %%
date
# Out:
# 583     201601
# 584     201602
# 585     201603
# 586     201604
# 587     201605
#          ...
# 4510    202006
# 4511    202007
# 4512    202008
# 4513    202009
# 4514    202010
# Name: YYYYMM, Length: 434, dtype: int64
